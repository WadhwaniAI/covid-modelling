# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd

import datetime
import copy
import json

import sys
sys.path.append('../../')

from data.dataloader import get_covid19india_api_data
from data.processing import get_data

from main.seir.fitting import single_fitting_cycle, get_variable_param_ranges
from main.seir.forecast import get_forecast, create_region_csv, create_all_csvs, write_csv, plot_forecast
from utils.create_report import create_report

# %% [markdown]
# ## Load Covid19india Data

# %%
dataframes = get_covid19india_api_data()

# %%
predictions_dict = {}

# %% [markdown]
# ## Select Districts to fit on

# %%
# districts_to_show = [('Maharashtra', 'Pune'), 
#                      ('Maharashtra', 'Mumbai'), 
#                      ('Rajasthan', 'Jaipur'), 
#                      ('Gujarat', 'Ahmedabad'), 
#                      ('Karnataka', 'Bengaluru Urban'),
#                      ('Delhi', None)]

districts_to_show = [('Maharashtra', 'Mumbai'), ('Maharashtra', 'Pune')]

# %% [markdown]
# ## Perform M1 and M2 fits

# %%
for state, district in districts_to_show:
    predictions_dict[(state, district)] = {}
    predictions_dict[(state, district)]['m1'] = single_fitting_cycle(
        dataframes, state, district, train_period=7, val_period=7, 
        data_from_tracker=True, initialisation='intermediate', num_evals=700,
        which_compartments=['hospitalised', 'total_infected', 'deceased', 'recovered'])
    predictions_dict[(state, district)]['m2'] = single_fitting_cycle(
        dataframes, state, district, train_period=7, val_period=0, num_evals=700,
        train_on_val=True, data_from_tracker=True, initialisation='intermediate',
        which_compartments=['hospitalised', 'total_infected', 'deceased', 'recovered'])
    
    predictions_dict[(state, district)]['state'] = state
    predictions_dict[(state, district)]['dist'] = district
    predictions_dict[(state, district)]['fitting_date'] = datetime.datetime.now().strftime("%Y-%m-%d")
    predictions_dict[(state, district)]['datasource'] = 'covid19api' if predictions_dict[(state, district)]['m1']['data_from_tracker'] else 'municipality'
    predictions_dict[(state, district)]['variable_param_ranges'] = predictions_dict[(state, district)]['m1']['variable_param_ranges']
    predictions_dict[(state, district)]['data_last_date'] = predictions_dict[(state, district)]['m2']['data_last_date']
# Out:
# fitting to data with "train_on_val" set to False ..
# splitting data ..
# splitting data ..
# train
#            state district       date  hospitalised  total_infected  deceased  \
# 25  Maharashtra   Mumbai 2020-05-21       19606.8         25404.2     867.6
# 26  Maharashtra   Mumbai 2020-05-22       20731.4         27245.6     913.8
# 27  Maharashtra   Mumbai 2020-05-23       21719.0         28816.4     950.8
# 28  Maharashtra   Mumbai 2020-05-24       22515.0         30311.2     987.4
# 29  Maharashtra   Mumbai 2020-05-25       23382.0         31664.6    1025.0
#
#     recovered
# 25     4929.8
# 26     5600.4
# 27     6146.6
# 28     6808.8
# 29     7257.6
# val
#           state district       date  hospitalised  total_infected  deceased  \
# 0  Maharashtra   Mumbai 2020-05-26       24167.6         32998.2    1062.2
# 1  Maharashtra   Mumbai 2020-05-27       24813.4         33986.8    1091.6
# 2  Maharashtra   Mumbai 2020-05-28       24211.0         35280.8    1131.8
# 3  Maharashtra   Mumbai 2020-05-29       23602.0         36374.4    1164.2
# 4  Maharashtra   Mumbai 2020-05-30       23179.4         37790.6    1208.6
# 5  Maharashtra   Mumbai 2020-05-31       20851.0         38442.0    1227.0
# 6  Maharashtra   Mumbai 2020-06-01       22795.0         41099.0    1319.0
#
#    recovered
# 0     7768.4
# 1     8081.8
# 2     9938.0
# 3    11608.2
# 4    13402.6
# 5    16364.0
# 6    16985.0
# 100%|██████████| 700/700 [00:58<00:00, 11.90trial/s, best loss: 3.957641671366321]
# best parameters
#  {'E_hosp_ratio': 0.5347674439881508, 'I_hosp_ratio': 0.46403812942042466, 'P_fatal': 0.03515997012972282, 'P_severe': 0.5444952672925958, 'T_inc': 4.998686369814015, 'T_inf': 3.1421210380511537, 'T_recov_severe': 56.647208240108746, 'lockdown_R0': 1.0724620152691908}
# fitting to data with "train_on_val" set to True ..
# splitting data ..
# splitting data ..
# train
#            state district       date  hospitalised  total_infected  deceased  \
# 32  Maharashtra   Mumbai 2020-05-28       24211.0         35280.8    1131.8
# 33  Maharashtra   Mumbai 2020-05-29       23602.0         36374.4    1164.2
# 34  Maharashtra   Mumbai 2020-05-30       23179.4         37790.6    1208.6
# 35  Maharashtra   Mumbai 2020-05-31       20851.0         38442.0    1227.0
# 36  Maharashtra   Mumbai 2020-06-01       22795.0         41099.0    1319.0
#
#     recovered
# 32     9938.0
# 33    11608.2
# 34    13402.6
# 35    16364.0
# 36    16985.0
# val
#  None
# 100%|██████████| 700/700 [01:26<00:00,  8.08trial/s, best loss: 8.666424205494742]
# best parameters
#  {'E_hosp_ratio': 0.5982204672631987, 'I_hosp_ratio': 0.33493978714599276, 'P_fatal': 0.016628245379488822, 'P_severe': 0.37952268506328757, 'T_inc': 4.891837398967358, 'T_inf': 3.5709638621264306, 'T_recov_severe': 18.878640372788137, 'lockdown_R0': 1.2348519315694817}
# fitting to data with "train_on_val" set to False ..
# splitting data ..
# splitting data ..
# train
#            state district       date  hospitalised  total_infected  deceased  \
# 25  Maharashtra     Pune 2020-05-21        2583.4          4710.6     233.0
# 26  Maharashtra     Pune 2020-05-22        2737.4          5032.8     244.6
# 27  Maharashtra     Pune 2020-05-23        2901.2          5336.6     254.2
# 28  Maharashtra     Pune 2020-05-24        3034.4          5670.6     263.8
# 29  Maharashtra     Pune 2020-05-25        3171.0          5994.8     273.4
#
#     recovered
# 25     1894.2
# 26     2050.8
# 27     2181.2
# 28     2372.4
# 29     2550.4
# val
#           state district       date  hospitalised  total_infected  deceased  \
# 0  Maharashtra     Pune 2020-05-26        3258.4          6304.6     282.2
# 1  Maharashtra     Pune 2020-05-27        3337.0          6547.4     289.8
# 2  Maharashtra     Pune 2020-05-28        3416.0          6855.6     299.0
# 3  Maharashtra     Pune 2020-05-29        3503.0          7096.0     306.6
# 4  Maharashtra     Pune 2020-05-30        3587.2          7382.2     316.0
# 5  Maharashtra     Pune 2020-05-31        3658.0          7537.0     320.0
# 6  Maharashtra     Pune 2020-06-01        3914.0          8045.0     338.0
#
#    recovered
# 0     2764.0
# 1     2920.6
# 2     3140.6
# 3     3286.4
# 4     3479.0
# 5     3559.0
# 6     3793.0
# 100%|██████████| 700/700 [01:31<00:00,  7.66trial/s, best loss: 2.77547720384739]
# best parameters
#  {'E_hosp_ratio': 0.6338285234081293, 'I_hosp_ratio': 0.40781394572424157, 'P_fatal': 0.12216113951525649, 'P_severe': 0.8694257516352561, 'T_inc': 4.9089642580814195, 'T_inf': 3.560955402948424, 'T_recov_severe': 17.976147356662924, 'lockdown_R0': 1.3916196718556584}
# fitting to data with "train_on_val" set to True ..
# splitting data ..
# splitting data ..
# train
#            state district       date  hospitalised  total_infected  deceased  \
# 32  Maharashtra     Pune 2020-05-28        3416.0          6855.6     299.0
# 33  Maharashtra     Pune 2020-05-29        3503.0          7096.0     306.6
# 34  Maharashtra     Pune 2020-05-30        3587.2          7382.2     316.0
# 35  Maharashtra     Pune 2020-05-31        3658.0          7537.0     320.0
# 36  Maharashtra     Pune 2020-06-01        3914.0          8045.0     338.0
#
#     recovered
# 32     3140.6
# 33     3286.4
# 34     3479.0
# 35     3559.0
# 36     3793.0
# val
#  None
# 100%|██████████| 700/700 [01:31<00:00,  7.69trial/s, best loss: 3.9285011668081657]
# best parameters
#  {'E_hosp_ratio': 0.7244957608186424, 'I_hosp_ratio': 0.4786485228390249, 'P_fatal': 0.037132845257531855, 'P_severe': 0.4243549492414168, 'T_inc': 4.399488241504641, 'T_inf': 3.9972852768693805, 'T_recov_severe': 28.127402965556456, 'lockdown_R0': 1.321959178143434}

# %% [markdown]
# ## Create Master Loss Dataframe

# %% [markdown]
# ### M1 Loss

# %%
starting_key = list(predictions_dict.keys())[0]

loss_columns = pd.MultiIndex.from_product([predictions_dict[starting_key]['m1']['df_loss'].columns, predictions_dict[starting_key]['m1']['df_loss'].index])
loss_index = predictions_dict.keys()

df_loss_master = pd.DataFrame(columns=loss_columns, index=loss_index)
for key in predictions_dict.keys():
    df_loss_master.loc[key, :] = np.around(predictions_dict[key]['m1']['df_loss'].values.T.flatten().astype('float'), decimals=2)
    
df_loss_master
# Out:
#                           train                                    \
#                    hospitalised total_infected deceased recovered
# Maharashtra Mumbai         1.32           1.12     1.61      4.25
#             Pune           2.06           1.04     1.61      3.01
#
#                             val
#                    hospitalised total_infected deceased recovered
# Maharashtra Mumbai        12.18           6.99      2.3     18.26
#             Pune           9.93           4.49     9.97       3.1

# %% [markdown]
# ### M2 Loss

# %%
starting_key = list(predictions_dict.keys())[0]

loss_columns = pd.MultiIndex.from_product([predictions_dict[starting_key]['m2']['df_loss'].columns, predictions_dict[starting_key]['m2']['df_loss'].index])
loss_index = predictions_dict.keys()

df_loss_master = pd.DataFrame(columns=loss_columns, index=loss_index)
for key in predictions_dict.keys():
    df_loss_master.loc[key, :] = np.around(predictions_dict[key]['m2']['df_loss'].values.T.flatten().astype('float'), decimals=2)
    
df_loss_master
# Out:
#                           train
#                    hospitalised total_infected deceased recovered
# Maharashtra Mumbai         6.58           1.25     1.65     12.55
#             Pune            2.5           1.68        1      2.82

# %% [markdown]
# ## Plot Forecasts

# %%
for region in predictions_dict.keys():
    predictions_dict[region]['forecast'] = plot_forecast(predictions_dict[region], region, both_forecasts=False, error_bars=True)
# Out:
# getting forecasts ..
# getting forecasts ..

# %% [markdown]
# ## Create Report

# %%
for region in predictions_dict.keys():
    create_report(predictions_dict[region])

# %% [markdown]
# ## Create and Save Output CSV

# %%
df_output = create_all_csvs(predictions_dict, icu_fraction=0.02)
# Out:
# compiling csv data ..
# getting forecasts ..
# compiling csv data ..
# getting forecasts ..

# %%
write_csv(df_output)
