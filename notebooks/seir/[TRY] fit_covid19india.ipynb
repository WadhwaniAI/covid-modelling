# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
from hyperopt import hp, tpe, fmin, Trials
from tqdm import tqdm
# from tqdm.notebook import tqdm

from collections import OrderedDict
import itertools
from functools import partial
import datetime
from joblib import Parallel, delayed
import copy

from data.dataloader import get_jhu_data, get_covid19india_api_data
from data.processing import get_district_time_series

from models.seir.seir_testing import SEIR_Testing
from main.seir.optimiser import Optimiser
from main.seir.losses import Loss_Calculator
from utils.plotting import create_plots

# %% [markdown]
# ## Load Covid19india Data

# %%
dataframes = get_covid19india_api_data()

# %%
dataframes['df_raw_data'].groupby('detecteddistrict').count()
# Out:
#                   agebracket  backupnotes  \
# detecteddistrict
#                         7652         7652
# Adilabad                  18           18
# Agar Malwa                 7            7
# Agra                     374          374
# Ahmadabad               2181         2181
# ...                      ...          ...
# West Godavari             51           51
# Y.S.R Kadapa               3            3
# Y.S.R.                    55           55
# Yamunanagar                3            3
# Yavatmal                  15           15
#
#                   contractedfromwhichpatientsuspected  currentstatus  \
# detecteddistrict
#                                                  7652           7652
# Adilabad                                           18             18
# Agar Malwa                                          7              7
# Agra                                              374            374
# Ahmadabad                                        2181           2181
# ...                                               ...            ...
# West Godavari                                      51             51
# Y.S.R Kadapa                                        3              3
# Y.S.R.                                             55             55
# Yamunanagar                                         3              3
# Yavatmal                                           15             15
#
#                   dateannounced  detectedcity  detectedstate  \
# detecteddistrict
#                            7652          7652           7652
# Adilabad                     18            18             18
# Agar Malwa                    7             7              7
# Agra                        374           374            374
# Ahmadabad                  2181          2181           2181
# ...                         ...           ...            ...
# West Godavari                51            51             51
# Y.S.R Kadapa                  3             3              3
# Y.S.R.                       55            55             55
# Yamunanagar                   3             3              3
# Yavatmal                     15            15             15
#
#                   estimatedonsetdate  gender  nationality  notes  \
# detecteddistrict
#                                 7652    7652         7652   7652
# Adilabad                          18      18           18     18
# Agar Malwa                         7       7            7      7
# Agra                             374     374          374    374
# Ahmadabad                       2181    2181         2181   2181
# ...                              ...     ...          ...    ...
# West Godavari                     51      51           51     51
# Y.S.R Kadapa                       3       3            3      3
# Y.S.R.                            55      55           55     55
# Yamunanagar                        3       3            3      3
# Yavatmal                          15      15           15     15
#
#                   patientnumber  source1  source2  source3  statecode  \
# detecteddistrict
#                            7652     7652     7652     7652       7652
# Adilabad                     18       18       18       18         18
# Agar Malwa                    7        7        7        7          7
# Agra                        374      374      374      374        374
# Ahmadabad                  2181     2181     2181     2181       2181
# ...                         ...      ...      ...      ...        ...
# West Godavari                51       51       51       51         51
# Y.S.R Kadapa                  3        3        3        3          3
# Y.S.R.                       55       55       55       55         55
# Yamunanagar                   3        3        3        3          3
# Yavatmal                     15       15       15       15         15
#
#                   statepatientnumber  statuschangedate  typeoftransmission
# detecteddistrict
#                                 7652              7652                7652
# Adilabad                          18                18                  18
# Agar Malwa                         7                 7                   7
# Agra                             374               374                 374
# Ahmadabad                       2181              2181                2181
# ...                              ...               ...                 ...
# West Godavari                     51                51                  51
# Y.S.R Kadapa                       3                 3                   3
# Y.S.R.                            55                55                  55
# Yamunanagar                        3                 3                   3
# Yavatmal                          15                15                  15
#
# [447 rows x 19 columns]

# %% [markdown]
# ## Process Covid19india Data

# %%
df_district = get_district_time_series(dataframes, state='Maharashtra', district='Mumbai')

# %% [markdown]
# ## Create Train-Val Split

# %%
def return_train_val(df_district, val_rollingmean=False, val_size=5):
    df_true_fitting = copy.copy(df_district)
    df_true_fitting['total_infected'] = df_true_fitting['total_infected'].rolling(5, center=True).mean()
    df_true_fitting = df_true_fitting[np.logical_not(df_true_fitting['total_infected'].isna())]
    df_true_fitting.reset_index(inplace=True, drop=True)
    
    df_train = df_true_fitting.iloc[:-(val_size-2), :]
    df_train = pd.concat([df_true_fitting.iloc[:-val_size, :], df_district.iloc[-(val_size+2):-val_size, :]], ignore_index=True)
    if val_rollingmean:
        df_val = pd.concat([df_true_fitting.iloc[-(val_size-2):, :], df_district.iloc[-2:, :]], ignore_index=True)
    else:
        df_val = df_district.iloc[-val_size:, :]
    df_val.reset_index(inplace=True, drop=True)
    return df_train, df_val, df_true_fitting

# %% [markdown]
# ## Init Optimiser

# %%
optimiser = Optimiser()

# %%
default_params = optimiser.init_default_params(df_train)

# %% [markdown]
# ## Run Optimisation

# %% [markdown]
# ### Gridsearch

# %%
variable_param_ranges = {
    'R0' : np.linspace(1.8, 3, 13), 
    'P_severe' : np.linspace(0.3, 0.9, 25),
    'intervention_amount' : np.linspace(0.4, 1, 31)
}

loss_array, list_of_param_dicts = optimiser.gridsearch(df_train, default_params, variable_param_ranges, method='rmse', loss_indices=None)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10075.0), HTML(value='')))

# %% [markdown]
# ### Bayes Opt

# %%
variable_param_ranges = {
    'R0' : hp.uniform('R0', 1.6, 4),
    'T_inc' : hp.uniform('T_inc', 4, 5),
    'T_inf' : hp.uniform('T_inf', 3, 4),
    'T_recov_severe' : hp.uniform('T_recov_severe', 9, 20),
    'P_severe' : hp.uniform('P_severe', 0.3, 0.99),
    'intervention_amount' : hp.uniform('intervention_amount', 0.3, 1)
}
best, trials = optimiser.bayes_opt(df_train, default_params, variable_param_ranges, method='rmse', num_evals=1000, loss_indices=None)
# Out:
# 100%|██████████| 1000/1000 [00:37<00:00, 26.42trial/s, best loss: 47.51288547030464]

# %%
best
# Out:
# {'P_severe': 0.9897378319875836,
#  'R0': 3.8403113848292065,
#  'T_inc': 4.06372680221047,
#  'T_inf': 3.0236906533874137,
#  'T_recov_severe': 10.34126352167355,
#  'intervention_amount': 0.7814749784477073}

# %%
df_prediction = optimiser.solve(best, default_params, df_train)

# %%
fig, ax = plt.subplots(figsize=(12, 12))
ax.plot(df_district['date'], df_district['total_infected'], label='Confirmed Cases (Observed)')
ax.plot(df_true_fitting['date'], df_true_fitting['total_infected'], label='Confirmed Cases (Rolling Avg(5))')
ax.xaxis.set_major_locator(mdates.DayLocator(interval=15))
ax.xaxis.set_minor_locator(mdates.DayLocator(interval=1))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.ylabel('No of People')
plt.xlabel('Time')
plt.legend()
plt.title('Rolling Avg vs Observed (Mumbai)')
plt.grid()
plt.show()

fig, ax = plt.subplots(figsize=(12, 12))
ax.plot(df_train['date'], df_train['total_infected'], color='orange', label='Confirmed Cases (Rolling Avg (5))')
ax.plot(df_prediction['date'], df_prediction['total_infected'], '-g', label='Confirmed Cases (Predicted)')
ax.plot([df_train.iloc[-1, :]['date'], df_train.iloc[-1, :]['date']], [min(df_true_fitting['total_infected']), max(df_true_fitting['total_infected'])], '--r', label='Train Test Boundary')
ax.xaxis.set_major_locator(mdates.DayLocator(interval=15))
ax.xaxis.set_minor_locator(mdates.DayLocator(interval=1))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.ylabel('No of People')
plt.xlabel('Time')
plt.legend()
plt.title('Total Confirmed Cases')
plt.grid()
plt.show()

# %%
df_prediction = optimiser.solve(best, default_params, df_train, end_date=df_true_fitting.iloc[-1, :]['date'])

# %%
fig, ax = plt.subplots(figsize=(12, 12))
ax.plot(df_district['date'], df_district['total_infected'], label='Confirmed Cases (Observed)')
ax.plot(df_true_fitting['date'], df_true_fitting['total_infected'], color='orange', label='Confirmed Cases (Rolling Avg (5))')
ax.plot(df_prediction['date'], df_prediction['total_infected'], '-g', label='Confirmed Cases (Predicted)')
ax.plot([df_train.iloc[-1, :]['date'], df_train.iloc[-1, :]['date']], [min(df_true_fitting['total_infected']), max(df_true_fitting['total_infected'])], '--r', label='Train Test Boundary')
ax.xaxis.set_major_locator(mdates.DayLocator(interval=15))
ax.xaxis.set_minor_locator(mdates.DayLocator(interval=1))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.ylabel('No of People')
plt.xlabel('Time')
plt.legend()
plt.title('Total Confirmed Cases Extrapolated (Mumbai)')
plt.grid()
plt.show()

# %%
def solve_for_district(dataframes, state, district):
    df_district = get_district_time_series(dataframes, state=state, district=district)
    if district == None:
        district = ''
        
    df_train, df_val, df_true_fitting = return_train_val(df_district, val_rollingmean=False, val_size=5)

    print('train\n', df_train.tail())
    print('val\n', df_val)

    optimiser = Optimiser()

    default_params = optimiser.init_default_params(df_train)

    variable_param_ranges = {
        'R0' : hp.uniform('R0', 1.6, 4),
        'T_inc' : hp.uniform('T_inc', 4, 5),
        'T_inf' : hp.uniform('T_inf', 3, 4),
        'T_recov_severe' : hp.uniform('T_recov_severe', 9, 20),
        'P_severe' : hp.uniform('P_severe', 0.3, 0.99),
        'intervention_amount' : hp.uniform('intervention_amount', 0, 1)
    }
    best, trials = optimiser.bayes_opt(df_train, default_params, variable_param_ranges, method='rmse', num_evals=1500, loss_indices=[-7, None])

    print('best parameters\n', best)
    
    df_prediction = optimiser.solve(best, default_params, df_train)

    fig, ax = plt.subplots(figsize=(12, 12))
    ax.plot(df_district['date'], df_district['total_infected'], label='Confirmed Cases (Observed)')
    ax.plot(df_true_fitting['date'], df_true_fitting['total_infected'], label='Confirmed Cases (Rolling Avg(5))')
    ax.plot([df_train.iloc[-1, :]['date'], df_train.iloc[-1, :]['date']], [min(df_train['total_infected']), max(df_val['total_infected'])], '--r', label='Train Test Boundary')
    ax.xaxis.set_major_locator(mdates.DayLocator(interval=15))
    ax.xaxis.set_minor_locator(mdates.DayLocator(interval=1))
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
    plt.ylabel('No of People')
    plt.xlabel('Time')
    plt.legend()
    plt.title('Rolling Avg vs Observed ({} {})'.format(state, district))
    plt.grid()
#     plt.savefig('../../plots/observed_{}_{}.png'.format(state, district))
    plt.show()

    fig, ax = plt.subplots(figsize=(12, 12))
    ax.plot(df_train['date'], df_train['total_infected'], color='orange', label='Confirmed Cases (Rolling Avg (5))')
    ax.plot(df_prediction['date'], df_prediction['total_infected'], '-g', label='Confirmed Cases (Predicted)')
    ax.plot([df_train.iloc[-1, :]['date'], df_train.iloc[-1, :]['date']], [min(df_train['total_infected']), max(df_val['total_infected'])], '--r', label='Train Test Boundary')
    ax.xaxis.set_major_locator(mdates.DayLocator(interval=15))
    ax.xaxis.set_minor_locator(mdates.DayLocator(interval=1))
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
    plt.ylabel('No of People')
    plt.xlabel('Time')
    plt.legend()
    plt.title('Total Confirmed Cases ({} {})'.format(state, district))
    plt.grid()
#     plt.savefig('../../plots/predictions_{}_{}.png'.format(state, district))
    plt.show()
    
    return best, default_params, optimiser, df_prediction, df_district

# %%
df_raw_data = copy.copy(dataframes['df_raw_data'])
district_wise_counts = df_raw_data.groupby('detecteddistrict').count().iloc[:, 0].reset_index()
district_wise_counts.columns = ['detecteddistrict', 'count']
district_wise_counts.sort_values('count', ascending=False)
district_wise_counts.reset_index(inplace=True, drop=True)
district_100_plus = district_wise_counts[district_wise_counts['count'] > 100]
district_100_plus.reset_index(inplace=True, drop=True)

for i, row in district_100_plus.iterrows():
    district_100_plus.loc[i, 'detectedstate'] = df_raw_data[df_raw_data['detecteddistrict'] == row['detecteddistrict']].groupby('detectedstate').count().sort_values('detecteddistrict').index[-1]
    
district_100_plus = district_100_plus[district_100_plus['detecteddistrict'] != '']
district_to_plot = [[row['detectedstate'], row['detecteddistrict']] for i, row in district_100_plus.iterrows()]
district_to_plot.append(['Delhi', None])

# %%
district_to_plot = [['Maharashtra', 'Mumbai'], ['Maharashtra', 'Pune'], ['Delhi', None], ['Karnataka', 'Bengaluru'], ['Gujarat', 'Ahmadabad']]

# %%
predictions_dict = {}

for state, district in district_to_plot:
    print('state - {}, district - {}'.format(state, district))
    best, default_params, optimiser, df_prediction, df_district = solve_for_district(dataframes, state, district)
    predictions_dict[(state, district)] = {}
    for name in ['best', 'default_params', 'optimiser', 'df_prediction', 'df_district']:
        predictions_dict[(state, district)][name] = eval(name)
# Out:
# state - Maharashtra, district - Mumbai
# train
#           date  total_infected
# 31 2020-04-13          1527.2
# 32 2020-04-14          1712.6
# 33 2020-04-15          1870.0
# 34 2020-04-16          2073.0
# 35 2020-04-17          2085.0
# val
#          date  total_infected
# 0 2020-04-18            2268
# 1 2020-04-19            2268
# 2 2020-04-20            2455
# 3 2020-04-21            2455
# 4 2020-04-22            2687
# 100%|██████████| 1500/1500 [01:12<00:00, 20.75trial/s, best loss: 132.14284478764418]
# best parameters
#  {'P_severe': 0.9253382567537899, 'R0': 3.9990878143062187, 'T_inc': 4.2716397785789395, 'T_inf': 3.039474772457308, 'T_recov_severe': 18.129061058331907, 'intervention_amount': 0.5177889314464953}
# state - Maharashtra, district - Pune
# train
#           date  total_infected
# 33 2020-04-13           317.2
# 34 2020-04-14           360.4
# 35 2020-04-15           408.6
# 36 2020-04-16           473.0
# 37 2020-04-17           504.0
# val
#          date  total_infected
# 0 2020-04-18             591
# 1 2020-04-19             591
# 2 2020-04-20             591
# 3 2020-04-21             591
# 4 2020-04-22             680
# 100%|██████████| 1500/1500 [01:08<00:00, 21.93trial/s, best loss: 7.271077735010921]
# best parameters
#  {'P_severe': 0.7810377852659054, 'R0': 2.267832793753206, 'T_inc': 4.528013117825062, 'T_inf': 3.560266613517765, 'T_recov_severe': 13.53499709150219, 'intervention_amount': 0.9149783006252867}
# state - Delhi, district - None
# train
#           date  total_infected
# 44 2020-04-17          1764.2
# 45 2020-04-18          1864.8
# 46 2020-04-19          1968.0
# 47 2020-04-20          2081.0
# 48 2020-04-21          2156.0
# val
#          date  total_infected
# 0 2020-04-22            2248
# 1 2020-04-23            2376
# 2 2020-04-24            2514
# 3 2020-04-25            2625
# 4 2020-04-26            2918
# 100%|██████████| 1500/1500 [01:17<00:00, 19.24trial/s, best loss: 14.13384994563457]
# best parameters
#  {'P_severe': 0.9883333644111025, 'R0': 3.9983218394142366, 'T_inc': 4.225279484432358, 'T_inf': 3.828598027259423, 'T_recov_severe': 14.32565165917169, 'intervention_amount': 0.2984055095253308}
# state - Karnataka, district - Bengaluru
# train
#           date  total_infected
# 36 2020-04-16            80.2
# 37 2020-04-17            84.2
# 38 2020-04-18            87.8
# 39 2020-04-19            91.0
# 40 2020-04-20            91.0
# val
#          date  total_infected
# 0 2020-04-21              91
# 1 2020-04-22              93
# 2 2020-04-23             103
# 3 2020-04-24             122
# 4 2020-04-25             135
# 100%|██████████| 1500/1500 [01:08<00:00, 21.80trial/s, best loss: 1.4658006101006458]
# best parameters
#  {'P_severe': 0.741441946442446, 'R0': 2.126678047407295, 'T_inc': 4.387417493475502, 'T_inf': 3.7455023393698466, 'T_recov_severe': 15.171748966305165, 'intervention_amount': 0.44676179339926936}
# state - Gujarat, district - Ahmadabad
# train
#           date  total_infected
# 26 2020-04-17           716.2
# 27 2020-04-18           875.8
# 28 2020-04-19          1041.4
# 29 2020-04-20          1248.0
# 30 2020-04-21          1373.0
# val
#          date  total_infected
# 0 2020-04-22            1501
# 1 2020-04-23            1652
# 2 2020-04-24            1821
# 3 2020-04-25            2003
# 4 2020-04-26            2181
# 100%|██████████| 1500/1500 [01:07<00:00, 22.32trial/s, best loss: 36.47237702308812]
# best parameters
#  {'P_severe': 0.7976117732813931, 'R0': 3.777679102673702, 'T_inc': 4.75231689950452, 'T_inf': 3.092015233569401, 'T_recov_severe': 9.660851921125595, 'intervention_amount': 0.741151695567284}

# %%
df_result = pd.DataFrame(columns=['state', 'district', 'train_rmse', 'train_mape', 'pre_intervention_r0', 'post_intervention_r0',
                                  'val_rmse_observed', 'val_mape_observed', 'val_rmse_rolling', 'val_mape_rolling'])

# %%
def create_classification_report(predictions_dict):

    loss_calculator = Loss_Calculator()
    for i, key in enumerate(predictions_dict.keys()):
        df_result.loc[i, 'state'] = key[0]
        df_result.loc[i, 'district'] = key[1]
        df_district = predictions_dict[key]['df_district']
        df_prediction = predictions_dict[key]['df_prediction']
        best = predictions_dict[key]['best']
        optimiser = predictions_dict[key]['optimiser']
        default_params = predictions_dict[key]['default_params']
        
        df_train, df_val, df_true_fitting = return_train_val(df_district, val_rollingmean=False, val_size=5)

        loss = loss_calculator._calc_mape(df_prediction.iloc[-10:, :]['total_infected'], df_train.iloc[-10:, :]['total_infected'])
        df_result.loc[i, 'train_mape'] = loss
        loss = loss_calculator._calc_rmse(df_prediction['total_infected'], df_train['total_infected'])
        df_result.loc[i, 'train_rmse'] = loss

        df_result.loc[i, 'pre_intervention_r0'] = best['R0']
        df_result.loc[i, 'post_intervention_r0'] = best['R0']*best['intervention_amount']

        df_prediction = optimiser.solve(best, default_params, df_train, end_date=df_val.iloc[-1, :]['date'])
        df_prediction = df_prediction[df_prediction['date'].isin(df_val['date'])]
        df_prediction.reset_index(inplace=True, drop=True)

        loss = loss_calculator._calc_mape(df_prediction['total_infected'], df_val['total_infected'])
        df_result.loc[i, 'val_mape_observed'] = loss
        loss = loss_calculator._calc_rmse(df_prediction['total_infected'], df_val['total_infected'])
        df_result.loc[i, 'val_rmse_observed'] = loss

        _, df_val, _ = return_train_val(df_district, val_rollingmean=True, val_size=5)

        loss = loss_calculator._calc_mape(df_prediction['total_infected'], df_val['total_infected'])
        df_result.loc[i, 'val_mape_rolling'] = loss
        loss = loss_calculator._calc_rmse(df_prediction['total_infected'], df_val['total_infected'])
        df_result.loc[i, 'val_rmse_rolling'] = loss

    return df_result

# %%
def create_full_plots(predictions_dict):
    for i, key in enumerate(predictions_dict.keys()):
        
        df_district = predictions_dict[key]['df_district']
        df_prediction = predictions_dict[key]['df_prediction']
        best = predictions_dict[key]['best']
        optimiser = predictions_dict[key]['optimiser']
        default_params = predictions_dict[key]['default_params']
        
        df_train, df_val, df_true_fitting = return_train_val(df_district, val_rollingmean=False, val_size=5)
        df_prediction = optimiser.solve(best, default_params, df_train, end_date=df_val.iloc[-1, :]['date'])

        
        fig, ax = plt.subplots(figsize=(12, 12))
        ax.plot(df_district['date'], df_district['total_infected'], label='Confirmed Cases (Observed)')
        ax.plot(df_true_fitting['date'], df_true_fitting['total_infected'], color='orange', label='Confirmed Cases (Rolling Avg (5))')
        ax.plot(df_prediction['date'], df_prediction['total_infected'], '-g', label='Confirmed Cases (Predicted)')
        ax.plot([df_train.iloc[-1, :]['date'], df_train.iloc[-1, :]['date']], [min(df_train['total_infected']), max(df_val['total_infected'])], '--r', label='Train Test Boundary')
        ax.xaxis.set_major_locator(mdates.DayLocator(interval=15))
        ax.xaxis.set_minor_locator(mdates.DayLocator(interval=1))
        ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
        plt.ylabel('No of People')
        plt.xlabel('Time')
        plt.legend()
        plt.title('Total Confirmed Cases Extrapolated ({})'.format(key))
        plt.grid()
        plt.show()

# %%
create_full_plots(predictions_dict)

# %%
df_result = create_classification_report(predictions_dict)
df_result
# Out:
#          state   district train_rmse train_mape pre_intervention_r0  \
# 0  Maharashtra     Mumbai    62.6278    5.70444             3.99646
# 1  Maharashtra       Pune    12.1545    1.55857             2.24272
# 2        Delhi       None    148.841     1.2566             3.88225
# 3    Karnataka  Bengaluru    10.1382    1.30111             2.23261
# 4      Gujarat  Ahmadabad    21.7831     3.6205             3.30763
#
#   post_intervention_r0 val_rmse_observed val_mape_observed val_rmse_rolling  \
# 0              2.00285           1055.97           38.8279          1058.63
# 1              2.04203           140.291           18.9905           138.65
# 2              1.26718           64.1327           2.19508          58.3727
# 3             0.960027           13.3192            9.0328          12.9173
# 4              2.93614           788.806           35.4899          784.444
#
#   val_mape_rolling
# 0            39.11
# 1           18.816
# 2          1.70845
# 3          7.57923
# 4          34.7969

# %%
predictions_dict[('Maharashtra', 'Mumbai')]['best']
# Out:
# {'P_severe': 0.8425457796503185,
#  'R0': 3.996456545547218,
#  'T_inc': 4.024497407365177,
#  'T_inf': 3.1378676161876786,
#  'T_recov_severe': 15.469675501867707,
#  'intervention_amount': 0.5011559513978342}
